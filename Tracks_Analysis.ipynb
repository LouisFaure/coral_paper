# %% [markdown]
# # Data processing of tracks

# %% [markdown]
# ## Downloading and unpacking data

# %%
# !tar xzf Track_Data/test.tar.gz -C Track_Data/

# %% [markdown]
# ## Loading imaris statistical data

# %%
# !python preprocess_imaris.py Track_Data/Montipora2/
# Out:
# 100%|█████████████████████████████████████████████| 4/4 [00:02<00:00,  1.47it/s]

# %% [markdown]
# ## Processing tracks data

# %%
# !python -W ignore analysis_tracks.py Track_Data/Montipora2/
# Out:
# 2020-05-31 20:24:19,340 - Importing modules
# 2020-05-31 20:24:21,395 - Loading tracks, vectors and mouth positions
# 2020-05-31 20:24:22,004 - Plotting track speeds
# 2020-05-31 20:24:22,823 - Running parallel analysis
# 2020-05-31 20:24:23,063 - replicate 2: Making grid vector field
# 2020-05-31 20:24:23,064 - replicate 2: Data temporary saved in /tmp/tmpqk0dyune
# 2020-05-31 20:24:24,452 - replicate 0: Making grid vector field
# 2020-05-31 20:24:24,453 - replicate 0: Data temporary saved in /tmp/tmp7ttj91_w
# 2020-05-31 20:24:25,952 - replicate 2: Calculating FTLE
# 2020-05-31 20:24:26,339 - replicate 1: Making grid vector field
# 2020-05-31 20:24:26,340 - replicate 1: Data temporary saved in /tmp/tmp1i7v_xcf
# 2020-05-31 20:24:27,985 - replicate 3: Making grid vector field
# 2020-05-31 20:24:27,987 - replicate 3: Data temporary saved in /tmp/tmpn1w5t0gy
# 2020-05-31 20:24:29,659 - replicate 0: Calculating FTLE
# ...

# %% [markdown]
# ## Example of a report generated

# %%
import matplotlib.pyplot as plt
im=plt.imread("Track_Data/Montipora2/2020-02-18_montipora_1_stats/REPORT.png")

# %%
fig = plt.figure(figsize=(im.shape[1]/200, im.shape[0]/200), dpi=50)
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)
plt.imshow(im)
